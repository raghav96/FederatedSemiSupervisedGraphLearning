# %% [markdown]
# <a href="https://colab.research.google.com/github/raghav96/FederatedSemiSupervisedGraphLearning/blob/main/Capstone_Supervised_on_Server_and_Client_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supervised Federated Graph Learning
#
# This notebook has the scenario where
#
# *   There is an equal split of edges between different clients and the server.
# *   Supervised learning on the server and on the client
# * The classes of the nodes are split by random across the clients and the server
#
# Model used in this notebook is a GraphSage model

# %% [markdown]
# Getting all the required packages for the Python environment

# %%
# !pip install  dgl -f https://data.dgl.ai/wheels/cu117/repo.html
# !pip install  dglgo -f https://data.dgl.ai/wheels-test/repo.html
# !pip install torch_geometric
# Out:
# Looking in links: https://data.dgl.ai/wheels/cu117/repo.html
# Requirement already satisfied: dgl in /usr/local/lib/python3.10/dist-packages (1.1.2+cu117)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.11.2)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2023.7.22)
# Looking in links: https://data.dgl.ai/wheels-test/repo.html
# Requirement already satisfied: dglgo in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: typer>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (0.9.0)
# Requirement already satisfied: isort>=5.10.1 in /usr/local/lib/python3.10/dist-packages (from dglgo) (5.12.0)
# Requirement already satisfied: autopep8>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (2.0.4)
# Requirement already satisfied: numpydoc>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.5.0)
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.10.12)
# Requirement already satisfied: ruamel.yaml>=0.17.20 in /usr/local/lib/python3.10/dist-packages (from dglgo) (0.17.32)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from dglgo) (6.0.1)
# Requirement already satisfied: ogb>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.3.6)
# Requirement already satisfied: rdkit-pypi in /usr/local/lib/python3.10/dist-packages (from dglgo) (2022.9.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.2.2)
# Requirement already satisfied: pycodestyle>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from autopep8>=1.6.0->dglgo) (2.11.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8>=1.6.0->dglgo) (2.0.1)
# Requirement already satisfied: sphinx>=4.2 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->dglgo) (5.0.2)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->dglgo) (3.1.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.23.5)
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (4.66.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.5.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (2.0.4)
# Requirement already satisfied: outdated>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (0.2.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->dglgo) (4.5.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.20->dglgo) (0.2.7)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (3.2.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.4.0->dglgo) (8.1.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi->dglgo) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.10->numpydoc>=1.1.0->dglgo) (2.1.3)
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (67.7.2)
# Requirement already satisfied: littleutils in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (0.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2023.3.post1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.1.9)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.6)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.16.1)
# Requirement already satisfied: docutils<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.18.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.12.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->ogb>=1.3.3->dglgo) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->ogb>=1.3.3->dglgo) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->ogb>=1.3.3->dglgo) (1.3.0)
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.10/dist-packages (2.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.11.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.2.0)

# %% [markdown]
# # Model

# %%
import dgl
import torch
import torch.nn as nn
import torch.nn.functional as F
from dgl.nn import SAGEConv

class GraphSAGE(nn.Module):
    def __init__(self, in_feats, hid_feats, out_feats):
        super(GraphSAGE, self).__init__()
        self.conv1 = SAGEConv(in_feats, hid_feats, 'mean')
        self.conv2 = SAGEConv(hid_feats, out_feats, 'mean')

    def forward(self, g, in_feat):
        h = self.conv1(g, in_feat)
        h = F.relu(h)
        h = self.conv2(g, h)
        return h

# %% [markdown]
# # Client

# %%
import torch
from torch import nn, optim
from tqdm import tqdm
from dgl import DGLGraph
import copy
import numpy as np
import torch as th
import scipy.sparse as sp
from scipy.linalg import fractional_matrix_power, inv

import dgl
import networkx as nx

from sklearn.preprocessing import MinMaxScaler

from dgl.nn import APPNPConv

class Client:

    # def loss_fn(self, batch_graph, embeddings, negative_samples = 5):
    #     # Get the edges in the batch graph
    #     edges = batch_graph.edges()

    #     # Get the positive pairs (node and its neighbors)
    #     positive_pairs = torch.stack(edges)

    #     # Get the embeddings for the nodes in the positive pairs
    #     pos_u_embeddings = embeddings[positive_pairs[0]]
    #     pos_v_embeddings = embeddings[positive_pairs[1]]

    #     # Compute the similarity for the positive pairs (dot product is used as the similarity function)
    #     pos_similarity = torch.sum(pos_u_embeddings * pos_v_embeddings, dim=1)

    #     # Generate negative samples
    #     num_nodes = embeddings.shape[0]
    #     neg_v = torch.randint(0, num_nodes, (positive_pairs.shape[1], negative_samples))

    #     # Get the embeddings for the nodes in the negative samples
    #     neg_u_embeddings = pos_u_embeddings.unsqueeze(1).repeat(1, negative_samples, 1)
    #     neg_v_embeddings = embeddings[neg_v]

    #     # Compute the similarity for the negative samples
    #     neg_similarity = torch.sum(neg_u_embeddings * neg_v_embeddings, dim=2)

    #     # Compute the loss
    #     pos_loss = -F.logsigmoid(pos_similarity)
    #     neg_loss = -F.logsigmoid(-neg_similarity)

    #     # Combine the positive and negative loss
    #     loss = torch.mean(pos_loss) + torch.mean(neg_loss)

    #     return loss
    #   pos_score = torch.sum(embeddings[g.edges()[0]] * embeddings[g.edges()[1]], dim=1)
    #   neg_score = torch.sum(embeddings[g.edges()[0]] * embeddings[g.edges()[1]].flip(0), dim=1)
    #   return -torch.mean(F.logsigmoid(pos_score) + F.logsigmoid(-neg_score))

    def __init__(self, client_id, data, model, device, epoch, lr, l2norm, model_path, logging, writer) -> None:
        # log setting
        self.model_path = model_path
        self.logging = logging
        self.writer = writer

        # client setting
        self.client_id = client_id
        self.device = device
        self.data = data
        self.model = model.to(self.device)
        self.epoch = epoch
        self.hid_dim = 64

        self.Epoch = -1                    # record the FL round by self
        self.round = None                  # record the mask round of FL this round from the server
        self.val_acc = None
        self.model_param = None
        self.patience = 10
        self.epochs = args.local_epoch
        #self.loss_fn = nn.BCEWithLogitsLoss()
        self.loss_fn = nn.CrossEntropyLoss()
        self.graph = data.to(self.device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr, weight_decay=l2norm)

    def train(self):
        print('Client: {0}'.format(self.client_id))
        # Extract features, labels, and masks for training, validation, and testing
        #features = self.graph.ndata['feat']
        labels = self.graph.ndata['label']
        train_mask = self.graph.ndata['train_mask']
        val_mask = self.graph.ndata['val_mask']
        test_mask = self.graph.ndata['test_mask']
        #print(self.model)
        #print(self.graph)
        #print(self.loss_fn)

        best = float('inf')
        cnt_wait = 0

        # Define the optimizer and loss function
        #optimizer = torch.optim.Adam(self.model.parameters(), lr=0.005)

        # Training loop
        for epoch in range(self.epochs):
            self.model.train()
            logits = self.model(self.graph, self.graph.ndata['feat'])
            loss = self.loss_fn(logits[train_mask], labels[train_mask])

            #print(loss)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            if loss < best:
                best = loss
                cnt_wait = 0
                th.save(self.model.state_dict(), 'model' + '_' + str(self.client_id) + '.pkl')
                self.model_param = self.model.state_dict()
            else:
                cnt_wait += 1

            if cnt_wait == self.patience:
                print('Early stopping')
                break

            # Validation
            self.model.eval()
            with torch.no_grad():
                val_pred = torch.argmax(self.model(self.graph, self.graph.ndata['feat'])[val_mask], dim=1)
                val_labels = labels[val_mask]
                val_acc = (val_pred == val_labels).float().mean()
                print('Epoch: {0}, Loss: {1:0.4f} , Val Acc: {2:0.4f}'.format(epoch, loss.item(), 100*val_acc.item()))
                #print(f'Epoch {epoch+1}, Loss: {100*loss.item()}, Val Acc: {100*val_acc.item()}')

        # # Testing
        # self.model.eval()
        # with torch.no_grad():
        #     test_pred = torch.argmax(self.model(self.graph, self.graph.ndata['feat'])[test_mask], dim=1)
        #     test_labels = labels[test_mask]
        #     test_acc = (test_pred == test_labels).float().mean()
        #     print(f'Test Acc: {100*test_acc.item()}')
    # def train(self):
    #     print('Client: {0}'.format(self.client_id))
    #     best = float('inf')
    #     cnt_wait = 0
    #     for epoch in range(self.epochs):
    #         self.model.train()
    #         out = self.model(self.graph, self.graph.ndata['feat'].float())
    #         loss = self.loss_fn(self.graph, out)
    #         self.optimizer.zero_grad()

    #         # shuf_idx = np.random.permutation(self.n_node)
    #         # shuf_feat = self.feat[shuf_idx, :]
    #         # shuf_feat = shuf_feat.to(args.device)

    #         #out = self.model(self.graph, self.diff_graph, self.feat, shuf_feat, self.edge_weight)

    #         loss.backward()
    #         self.optimizer.step()

    #         print('Epoch: {0}, Loss: {1:0.4f}'.format(epoch, loss.item()))

    #         if loss < best:
    #             best = loss
    #             cnt_wait = 0
    #             th.save(self.model.state_dict(), 'model' + '_' + str(self.client_id) + '.pkl')
    #             self.model_param = self.model.state_dict()
    #         else:
    #             cnt_wait += 1

    #         if cnt_wait == self.patience:
    #             print('Early stopping')
    #             break

    def test(self):
        self.model.eval()
        with torch.no_grad():
            logits = self.model(self.graph)
            test_loss = self.loss_fn(logits[self.test_idx], self.labels[self.test_idx])
            test_acc =  (logits[self.test_idx].argmax(1) == self.labels[self.test_idx]).float().sum()
            test_acc = test_acc / len(self.test_idx)

        print("Client {:>2} Test: Test Loss: {:.4f} | Test Acc: {:.4f}".format(
            self.client_id, test_loss.item(), test_acc
        ))
        # save to disk
        torch.save(self.model_param, self.model_path + "client" + str(self.client_id) + '_model.ckpt')

        return test_acc

    # get the global model's parameters from parameter server
    def getParame(self, round, param):
        self.round = round
        # Right now we are copying all the layers of the global model into the local model's state dict
        # Loading the local model with the global model to finetune with the local data
        if self.model_param is not None:
            for layer_name in self.model_param:
                    param[layer_name] = copy.deepcopy(self.model_param[layer_name])
        self.model.load_state_dict(param)


    # upload the local model's parameters to parameter server
    def uploadParame(self):
        param = {}
        for layer_name in self.model_param:
            param[layer_name] = self.model_param[layer_name]
        return self.round, param

# %% [markdown]
# # Server

# %%
import torch
from torch import nn
import random
import copy

class Server:
    def __init__(self, data, globalModel, device, logging, writer) -> None:
        # log setting
        self.logging = logging
        self.writer = writer

        # server setting
        self.device = device
        self.Epoch = -1                        # record the FL round by self
        self.round = random.randint(0, 1e8)    # record the mask round of FL this round
        self.local_state_dict = []
        #self.val_acc = 0
        self.model = globalModel.to(self.device)
        self.global_state_dict = copy.deepcopy(globalModel.state_dict())
        self.graph = data.to(self.device)

        # loss function
        self.loss_fn = nn.CrossEntropyLoss()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=args.server_lr, weight_decay=args.server_weight_decay)
        self.supervised_loss = 0
        self.patience = 6
        self.epochs = args.server_epoch


    def train(self):
        # Extract features, labels, and masks for training, validation, and testing
        #features = self.graph.ndata['feat']
        labels = self.graph.ndata['label']
        train_mask = self.graph.ndata['train_mask']
        val_mask = self.graph.ndata['val_mask']
        test_mask = self.graph.ndata['test_mask']
        #print(self.model)
        #print(self.graph)
        #print(self.loss_fn)

        best = float('inf')
        cnt_wait = 0

        print('Server training')
        # Training loop
        for epoch in range(self.epochs):
            self.model.train()
            logits = self.model(self.graph, self.graph.ndata['feat'])
            loss = self.loss_fn(logits[train_mask], labels[train_mask])

            #print(loss)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            if loss < best:
                best = loss
                cnt_wait = 0
                th.save(self.model.state_dict(), 'model.pkl')
                self.model_param = self.model.state_dict()
            else:
                cnt_wait += 1

            if cnt_wait == self.patience:
                print('Early stopping')
                break

            # Validation
            self.model.eval()
            with torch.no_grad():
                val_pred = torch.argmax(self.model(self.graph, self.graph.ndata['feat'])[val_mask], dim=1)
                val_labels = labels[val_mask]
                val_acc = (val_pred == val_labels).float().mean()
                print('Epoch: {0}, Loss: {1:0.4f} , Val Acc: {2:0.4f}'.format(epoch, loss.item(), 100*val_acc.item()))
                #print(f'Epoch {epoch+1}, Loss: {100*loss.item()}, Val Acc: {100*val_acc.item()}')

        # Testing
        self.model.eval()
        with torch.no_grad():
            test_pred = torch.argmax(self.model(self.graph, self.graph.ndata['feat'])[test_mask], dim=1)
            test_labels = labels[test_mask]
            test_acc = (test_pred == test_labels).float().mean()
            print(f'Test Acc: {100*test_acc.item()}')

    # the global model is not complete
    def test(self):
        size = self.graph.num_nodes
        self.model.eval()  # Set the model to evaluation mode

        # Extract the labels from the graph
        labels = self.graph.ndata['label']

        with torch.no_grad():
            # Get the predictions for all nodes
            logits = self.model(self.graph, self.graph.ndata['feat'].float())

            # Calculate the predictions
            predictions = torch.argmax(logits, dim=1)

            # Calculate the accuracy
            correct_predictions = torch.sum(predictions == labels)
            total_predictions = len(labels)
            accuracy = correct_predictions.float() / total_predictions

        print(f"Server test error: \n Accuracy: {(100*accuracy.item()):>0.1f}\n")

    def aggregate(self):
        clientNum = len(self.local_state_dict)
        if clientNum == 0:
            return
        #self.val_acc /= clientNum
        self.Epoch += 1

        labels = self.graph.ndata['label']
        train_mask = self.graph.ndata['train_mask']
        val_mask = self.graph.ndata['val_mask']
        test_mask = self.graph.ndata['test_mask']

        #self.logging.info("Clients Val Avg Acc: {:>8f}".format(self.val_acc))
        #self.writer.add_scalar(f"val/acc/avg", self.val_acc, self.Epoch)

        # Training the model
        self.model.train()
        self.optimizer.zero_grad()

        # aggregate all parameter
        for layer_name in self.local_state_dict[0].keys():
            self.global_state_dict[layer_name] = torch.zeros_like(self.global_state_dict[layer_name])

            for localParame in self.local_state_dict:
                self.global_state_dict[layer_name].add_(localParame[layer_name])

            self.global_state_dict[layer_name].div_(clientNum)

        self.local_state_dict.clear()
        self.round = random.randint(0, 1e8)

        # Get the value of the model and calculating the loss
        logits = self.model(self.graph, self.graph.ndata['feat'])
        self.supervised_loss = self.loss_fn(logits[train_mask], labels[train_mask])

        self.supervised_loss.backward()
        self.optimizer.step()

    def sendParame(self):
        return self.round, self.global_state_dict

    def getParame(self, round, localParame):
        if round == self.round:
            self.local_state_dict.append(localParame)
            #self.val_acc += val_acc

# %% [markdown]
# # Federated Learning initialization and running

# %%
# init FL setting
def init_fed(args):

    ## Split data to the server and the client accordingly
    server_data, datasets = labels_in_server_split_subgraph(args)

    # init the roles of FL
    # 1.init server
    #ser_model = GCN(num_nodes, args.n_hidden, num_classes, num_rels, args.n_bases, args.n_hidden_layers, args.gpu)
    ser_model = GraphSAGE(args.in_channels, args.n_hidden, args.out_channels)
    server = Server(server_data, ser_model, args.gpu, logging, args.writer)
    # 2.init clients
    clients = []
    for i in range(args.num_client):
        #model = GCN(in_channels=args.in_channels, hidden_channels = args.n_hidden, num_layers=args.n_hidden_layers, out_channels= args.out_channels)
        model = GraphSAGE(args.in_channels, args.n_hidden, args.out_channels)
        client = Client(i, datasets[i], model, args.gpu, args.local_epoch, args.lr, args.l2norm, args.state_dir + args.run_mode + "/", logging, args.writer)
        clients.append(client)

    return server, clients


# FL process
def FedRunning(args, server, clients):
    server.train()

    for t in range(args.round):

        print(f"---------------------Round {t}---------------------")

        # The 0 step
        perm = list(range(args.num_client))
        random.shuffle(perm)
        perm = np.array(perm[:int(args.num_client * args.fraction)])

        # The 1 step
        for client in np.array(clients)[perm]:
            client.getParame(*server.sendParame())
            client.train()
            server.getParame(*client.uploadParame())

        # The 2 step
        server.aggregate()
        server.test()




    print(f"--------------------Finally Test--------------------")

    # test_acc = 0
    # for client in np.array(clients):
    #     client.getParame(*server.sendParame())
    #     #test_acc += client.test()
    # test_acc /= len(clients)
    # logging.info("Clients Test Avg Acc: {:>8f}".format(test_acc))

# %% [markdown]
# # Main code to execute

# %%
import sys
sys.path.append("../")
import copy
import torch
from torch.utils.data import random_split
from torch.utils.tensorboard import SummaryWriter
from dgl.data import load_data
from dgl.data import AsNodePredDataset
from dgl import edge_subgraph
import numpy as np
from torch_geometric.nn.models import GCN
import argparse
import json
import logging
import os
import random


# init directories
def init_dir(args):
    # logging
    if not os.path.exists(args.log_dir):
        os.makedirs(args.log_dir)

    # state
    if not os.path.exists(args.state_dir):
        os.makedirs(args.state_dir)
    if not os.path.exists(args.state_dir + args.run_mode + '/'):
        os.makedirs(args.state_dir + args.run_mode + '/')

    # tensorboard log
    if not os.path.exists(args.tb_log_dir):
        os.makedirs(args.tb_log_dir)


# init logger
def init_logger(args):
    log_file = os.path.join(args.log_dir, args.run_mode + '.log')

    logging.basicConfig(
        format='%(asctime)s [%(levelname)s] | %(message)s',
        datefmt="%Y-%m-%d %H:%M:%S",
        level=logging.INFO,
        filename=log_file,
        filemode='a+'
    )

    console = logging.StreamHandler()
    console.setLevel(logging.INFO)
    formatter = logging.Formatter('%(asctime)s [%(levelname)s] | %(message)s')
    console.setFormatter(formatter)
    logging.getLogger('').addHandler(console)


import random

def numbers_with_sum(n, k):
    """n numbers with sum k"""
    if n == 1:
        return [k]
    print(k)
    num = random.randint(1, k)
    return [num] + numbers_with_sum(n - 1, k - num)

def equal_split(n, k):
    if n <= 0:
        return "Number should be greater than 0"

    quotient, remainder = divmod(k, n)
    result = [quotient] * n

    for i in range(remainder):
        result[i] += 1

    return result

# Splits the dataset into a labels-in-server scenario
def labels_in_server_split_subgraph(args):
  # load data
  dataset = load_data(args)
  graph = dataset[0]
  # keep the same number of node and relation to each client
  num_nodes = graph.num_nodes()
  #print(num_nodes)
  num_edges = graph.num_edges()
  #print(num_edges)
  num_classes = dataset.num_classes
  #print(num_classes)
  num_clients = args.num_client
  #print(num_clients)

  # Split the graph into the number of nodes for each client
  #edges_split = sorted(numbers_with_sum(num_clients+1, num_edges));
  edges_split = equal_split(num_clients+1, num_edges)
  print(edges_split)

  # Get edges for each client based on split and create subgraph for the client
  edge_idx = [i for i in range(num_edges)]
  np.random.shuffle(edge_idx)
  edge_idx_splits = np.split(edge_idx,np.cumsum(edges_split))[:-1]
  #print(edge_idx_splits)


  # Add labels for servers
  datasets = []
  server_data = edge_subgraph(graph, edge_idx_splits[0])

  # Add subgraph to the client's dataset and push to array
  for i in range(1, num_clients+1):
    client_subgraph = edge_subgraph(graph, edge_idx_splits[i])
    datasets.append(client_subgraph)

  return server_data, datasets

class Args:
  dataset = "cora"
  state_dir = "../log/state/"
  log_dir = "../log/"
  tb_log_dir = "../log/tb_log/"
  labeled_rate = 0.7
  lr = 0.01
  l2norm = 0.01
  server_lr = 0.005
  server_weight_decay = 0.005
  num_cpu = 1
  run_mode = "Fed"
  num_client = 20
  fraction = 1
  round = 200
  local_epoch = 20
  server_epoch = 100
  n_hidden = 64
  input = 50
  n_hidden_layers = 2
  in_channels = 1433
  out_channels = 7
  seed = 12345
  gpu = '0'


args = Args()
args_str = str(args)

args.gpu = torch.device('cuda:' + args.gpu)
print(args.gpu)

# set random seed
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)

# create directories
init_dir(args)

# init writer
writer = SummaryWriter(args.tb_log_dir + args.run_mode + "/")
args.writer = writer

# init logger
init_logger(args)
logging.info(args_str)

if args.run_mode == 'Fed':
    # init FL setting
    server, clients = init_fed(args)
    # running
    FedRunning(args, server, clients)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: 6, Loss: 0.7288 , Val Acc: 38.7597
# Epoch: 7, Loss: 0.7287 , Val Acc: 41.0853
# Epoch: 8, Loss: 0.7287 , Val Acc: 38.7597
# Epoch: 9, Loss: 0.7287 , Val Acc: 41.0853
# Epoch: 10, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 11, Loss: 0.7287 , Val Acc: 41.0853
# Epoch: 12, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 13, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 14, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 15, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 16, Loss: 0.7286 , Val Acc: 40.3101
# Epoch: 17, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 18, Loss: 0.7286 , Val Acc: 40.3101
# Epoch: 19, Loss: 0.7287 , Val Acc: 38.7597
# Client: 18
# Epoch: 0, Loss: 0.6543 , Val Acc: 40.7692
# Epoch: 1, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 2, Loss: 0.6543 , Val Acc: 40.7692
# Epoch: 3, Loss: 0.6544 , Val Acc: 39.2308
# Epoch: 4, Loss: 0.6543 , Val Acc: 40.7692
# Epoch: 5, Loss: 0.6543 , Val Acc: 40.0000
# Epoch: 6, Loss: 0.6545 , Val Acc: 40.7692
# Epoch: 7, Loss: 0.6543 , Val Acc: 40.0000
# Epoch: 8, Loss: 0.6543 , Val Acc: 40.7692
# Epoch: 9, Loss: 0.6542 , Val Acc: 40.0000
# Epoch: 10, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 11, Loss: 0.6543 , Val Acc: 40.7692
# Epoch: 12, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 13, Loss: 0.6544 , Val Acc: 40.7692
# Epoch: 14, Loss: 0.6545 , Val Acc: 40.0000
# Epoch: 15, Loss: 0.6546 , Val Acc: 40.7692
# Epoch: 16, Loss: 0.6545 , Val Acc: 39.2308
# Epoch: 17, Loss: 0.6550 , Val Acc: 40.7692
# Epoch: 18, Loss: 0.6551 , Val Acc: 39.2308
# Early stopping
# Client: 4
# Epoch: 0, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 1, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 2, Loss: 0.7715 , Val Acc: 24.8120
# Epoch: 3, Loss: 0.7713 , Val Acc: 26.3158
# Epoch: 4, Loss: 0.7715 , Val Acc: 24.8120
# Epoch: 5, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 6, Loss: 0.7715 , Val Acc: 25.5639
# Epoch: 7, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 8, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 9, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 10, Loss: 0.7712 , Val Acc: 25.5639
# Epoch: 11, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 12, Loss: 0.7712 , Val Acc: 25.5639
# Epoch: 13, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 14, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 15, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 16, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 17, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 18, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 19, Loss: 0.7713 , Val Acc: 25.5639
# Client: 7
# Epoch: 0, Loss: 0.6991 , Val Acc: 30.0654
# Epoch: 1, Loss: 0.6990 , Val Acc: 30.7190
# Epoch: 2, Loss: 0.6992 , Val Acc: 30.0654
# Epoch: 3, Loss: 0.6990 , Val Acc: 30.7190
# Epoch: 4, Loss: 0.6993 , Val Acc: 30.7190
# Epoch: 5, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 6, Loss: 0.6995 , Val Acc: 31.3726
# Epoch: 7, Loss: 0.6992 , Val Acc: 31.3726
# Epoch: 8, Loss: 0.6997 , Val Acc: 31.3726
# Epoch: 9, Loss: 0.6996 , Val Acc: 31.3726
# Epoch: 10, Loss: 0.6998 , Val Acc: 30.7190
# Early stopping
# Client: 0
# Epoch: 0, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 1, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 2, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 3, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 4, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 5, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 6, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 7, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 8, Loss: 0.7805 , Val Acc: 20.0000
# Epoch: 9, Loss: 0.7805 , Val Acc: 21.3793
# Epoch: 10, Loss: 0.7805 , Val Acc: 20.0000
# Early stopping
# Client: 9
# Epoch: 0, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 1, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 2, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 3, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 4, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 5, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 6, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 7, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 8, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 9, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 10, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 11, Loss: 0.8330 , Val Acc: 39.2593
# Early stopping
# Client: 1
# Epoch: 0, Loss: 0.8504 , Val Acc: 27.5862
# Epoch: 1, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 2, Loss: 0.8508 , Val Acc: 28.2759
# Epoch: 3, Loss: 0.8500 , Val Acc: 30.3448
# Epoch: 4, Loss: 0.8506 , Val Acc: 28.9655
# Epoch: 5, Loss: 0.8500 , Val Acc: 30.3448
# Epoch: 6, Loss: 0.8503 , Val Acc: 29.6552
# Epoch: 7, Loss: 0.8501 , Val Acc: 28.9655
# Epoch: 8, Loss: 0.8500 , Val Acc: 29.6552
# Epoch: 9, Loss: 0.8504 , Val Acc: 28.9655
# Epoch: 10, Loss: 0.8499 , Val Acc: 29.6552
# Early stopping
# Client: 6
# Epoch: 0, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 1, Loss: 0.6942 , Val Acc: 34.7826
# Epoch: 2, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 3, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 4, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 5, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 6, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 7, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 8, Loss: 0.6943 , Val Acc: 35.5072
# Epoch: 9, Loss: 0.6943 , Val Acc: 36.2319
# Early stopping
# Client: 15
# Epoch: 0, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 1, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 2, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 3, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 4, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 5, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 6, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 7, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 8, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 9, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 10, Loss: 0.6647 , Val Acc: 30.0000
# Epoch: 11, Loss: 0.6643 , Val Acc: 30.0000
# Epoch: 12, Loss: 0.6648 , Val Acc: 30.0000
# Epoch: 13, Loss: 0.6643 , Val Acc: 30.0000
# Epoch: 14, Loss: 0.6650 , Val Acc: 28.5714
# Epoch: 15, Loss: 0.6644 , Val Acc: 30.7143
# Epoch: 16, Loss: 0.6653 , Val Acc: 28.5714
# Epoch: 17, Loss: 0.6645 , Val Acc: 30.7143
# Epoch: 18, Loss: 0.6655 , Val Acc: 28.5714
# Epoch: 19, Loss: 0.6646 , Val Acc: 30.7143
# Client: 3
# Epoch: 0, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 1, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 2, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 3, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 4, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 5, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 6, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 7, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 8, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 9, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 10, Loss: 0.6155 , Val Acc: 30.9353
# Early stopping
# Client: 19
# Epoch: 0, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 1, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 2, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 3, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 4, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 5, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 6, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 7, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 8, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 9, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 10, Loss: 0.7448 , Val Acc: 28.0822
# Early stopping
# Client: 2
# Epoch: 0, Loss: 0.7528 , Val Acc: 25.3165
# Epoch: 1, Loss: 0.7526 , Val Acc: 23.4177
# Epoch: 2, Loss: 0.7528 , Val Acc: 25.3165
# Epoch: 3, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 4, Loss: 0.7529 , Val Acc: 25.9494
# Epoch: 5, Loss: 0.7528 , Val Acc: 23.4177
# Epoch: 6, Loss: 0.7530 , Val Acc: 25.9494
# Epoch: 7, Loss: 0.7530 , Val Acc: 22.7848
# Epoch: 8, Loss: 0.7531 , Val Acc: 25.9494
# Epoch: 9, Loss: 0.7531 , Val Acc: 22.7848
# Epoch: 10, Loss: 0.7531 , Val Acc: 24.6835
# Early stopping
# Server test error:
#  Accuracy: 50.2
#
# ---------------------Round 186---------------------
# Client: 2
# Epoch: 0, Loss: 0.7530 , Val Acc: 24.6835
# Epoch: 1, Loss: 0.7530 , Val Acc: 24.6835
# Epoch: 2, Loss: 0.7529 , Val Acc: 24.6835
# Epoch: 3, Loss: 0.7530 , Val Acc: 25.3165
# Epoch: 4, Loss: 0.7529 , Val Acc: 24.6835
# Epoch: 5, Loss: 0.7530 , Val Acc: 25.3165
# Epoch: 6, Loss: 0.7529 , Val Acc: 24.0506
# Epoch: 7, Loss: 0.7529 , Val Acc: 25.3165
# Epoch: 8, Loss: 0.7528 , Val Acc: 24.0506
# Epoch: 9, Loss: 0.7528 , Val Acc: 24.6835
# Epoch: 10, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 11, Loss: 0.7527 , Val Acc: 23.4177
# Epoch: 12, Loss: 0.7528 , Val Acc: 25.3165
# Epoch: 13, Loss: 0.7526 , Val Acc: 24.0506
# Epoch: 14, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 15, Loss: 0.7526 , Val Acc: 24.0506
# Epoch: 16, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 17, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 18, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 19, Loss: 0.7527 , Val Acc: 24.0506
# Client: 13
# Epoch: 0, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 1, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 2, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 3, Loss: 0.7641 , Val Acc: 31.3869
# Epoch: 4, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 5, Loss: 0.7641 , Val Acc: 31.3869
# Epoch: 6, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 7, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 8, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 9, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 10, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 11, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 12, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 13, Loss: 0.7640 , Val Acc: 29.9270
# Early stopping
# Client: 5
# Epoch: 0, Loss: 0.7891 , Val Acc: 26.2411
# Epoch: 1, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 2, Loss: 0.7891 , Val Acc: 26.2411
# Epoch: 3, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 4, Loss: 0.7890 , Val Acc: 25.5319
# Epoch: 5, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 6, Loss: 0.7890 , Val Acc: 25.5319
# Epoch: 7, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 8, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 9, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 10, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 11, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 12, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 13, Loss: 0.7891 , Val Acc: 25.5319
# Early stopping
# Client: 17
# Epoch: 0, Loss: 0.8504 , Val Acc: 34.7826
# Epoch: 1, Loss: 0.8502 , Val Acc: 34.0580
# Epoch: 2, Loss: 0.8504 , Val Acc: 34.7826
# Epoch: 3, Loss: 0.8501 , Val Acc: 34.0580
# Epoch: 4, Loss: 0.8502 , Val Acc: 34.0580
# Epoch: 5, Loss: 0.8501 , Val Acc: 34.0580
# Epoch: 6, Loss: 0.8502 , Val Acc: 34.0580
# Epoch: 7, Loss: 0.8501 , Val Acc: 33.3333
# Epoch: 8, Loss: 0.8501 , Val Acc: 34.0580
# Epoch: 9, Loss: 0.8502 , Val Acc: 33.3333
# Epoch: 10, Loss: 0.8500 , Val Acc: 34.0580
# Epoch: 11, Loss: 0.8501 , Val Acc: 34.0580
# Epoch: 12, Loss: 0.8500 , Val Acc: 34.0580
# Epoch: 13, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 14, Loss: 0.8499 , Val Acc: 33.3333
# Epoch: 15, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 16, Loss: 0.8499 , Val Acc: 32.6087
# Epoch: 17, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 18, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 19, Loss: 0.8499 , Val Acc: 34.0580
# Client: 16
# Epoch: 0, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 1, Loss: 0.7287 , Val Acc: 38.7597
# Epoch: 2, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 3, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 4, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 5, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 6, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 7, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 8, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 9, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 10, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 11, Loss: 0.7286 , Val Acc: 40.3101
# Epoch: 12, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 13, Loss: 0.7286 , Val Acc: 40.3101
# Epoch: 14, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 15, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 16, Loss: 0.7286 , Val Acc: 39.5349
# Early stopping
# Client: 14
# Epoch: 0, Loss: 0.6809 , Val Acc: 37.5000
# Epoch: 1, Loss: 0.6808 , Val Acc: 35.4167
# Epoch: 2, Loss: 0.6809 , Val Acc: 37.5000
# Epoch: 3, Loss: 0.6808 , Val Acc: 35.4167
# Epoch: 4, Loss: 0.6810 , Val Acc: 37.5000
# Epoch: 5, Loss: 0.6808 , Val Acc: 35.4167
# Epoch: 6, Loss: 0.6810 , Val Acc: 37.5000
# Epoch: 7, Loss: 0.6809 , Val Acc: 35.4167
# Epoch: 8, Loss: 0.6811 , Val Acc: 37.5000
# Epoch: 9, Loss: 0.6809 , Val Acc: 35.4167
# Epoch: 10, Loss: 0.6810 , Val Acc: 37.5000
# Early stopping
# Client: 4
# Epoch: 0, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 1, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 2, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 3, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 4, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 5, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 6, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 7, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 8, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 9, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 10, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 11, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 12, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 13, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 14, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 15, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 16, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 17, Loss: 0.7713 , Val Acc: 25.5639
# Early stopping
# Client: 15
# Epoch: 0, Loss: 0.6654 , Val Acc: 27.8571
# Epoch: 1, Loss: 0.6647 , Val Acc: 30.7143
# Epoch: 2, Loss: 0.6649 , Val Acc: 27.8571
# Epoch: 3, Loss: 0.6648 , Val Acc: 30.0000
# Epoch: 4, Loss: 0.6646 , Val Acc: 29.2857
# Epoch: 5, Loss: 0.6651 , Val Acc: 30.0000
# Epoch: 6, Loss: 0.6645 , Val Acc: 29.2857
# Epoch: 7, Loss: 0.6651 , Val Acc: 29.2857
# Epoch: 8, Loss: 0.6646 , Val Acc: 29.2857
# Epoch: 9, Loss: 0.6648 , Val Acc: 28.5714
# Epoch: 10, Loss: 0.6647 , Val Acc: 30.0000
# Epoch: 11, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 12, Loss: 0.6648 , Val Acc: 30.0000
# Epoch: 13, Loss: 0.6644 , Val Acc: 29.2857
# Epoch: 14, Loss: 0.6648 , Val Acc: 30.0000
# Epoch: 15, Loss: 0.6644 , Val Acc: 29.2857
# Epoch: 16, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 17, Loss: 0.6646 , Val Acc: 29.2857
# Epoch: 18, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 19, Loss: 0.6647 , Val Acc: 29.2857
# Client: 1
# Epoch: 0, Loss: 0.8499 , Val Acc: 29.6552
# Epoch: 1, Loss: 0.8500 , Val Acc: 29.6552
# Epoch: 2, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 3, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 4, Loss: 0.8499 , Val Acc: 28.9655
# Epoch: 5, Loss: 0.8496 , Val Acc: 29.6552
# Epoch: 6, Loss: 0.8499 , Val Acc: 28.9655
# Epoch: 7, Loss: 0.8496 , Val Acc: 29.6552
# Epoch: 8, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 9, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 10, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 11, Loss: 0.8498 , Val Acc: 28.9655
# Epoch: 12, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 13, Loss: 0.8499 , Val Acc: 29.6552
# Epoch: 14, Loss: 0.8497 , Val Acc: 29.6552
# Early stopping
# Client: 0
# Epoch: 0, Loss: 0.7805 , Val Acc: 19.3103
# Epoch: 1, Loss: 0.7805 , Val Acc: 21.3793
# Epoch: 2, Loss: 0.7806 , Val Acc: 20.0000
# Epoch: 3, Loss: 0.7806 , Val Acc: 22.0690
# Epoch: 4, Loss: 0.7807 , Val Acc: 20.0000
# Epoch: 5, Loss: 0.7808 , Val Acc: 22.7586
# Epoch: 6, Loss: 0.7808 , Val Acc: 19.3103
# Epoch: 7, Loss: 0.7811 , Val Acc: 22.7586
# Epoch: 8, Loss: 0.7811 , Val Acc: 18.6207
# Epoch: 9, Loss: 0.7812 , Val Acc: 22.7586
# Early stopping
# Client: 6
# Epoch: 0, Loss: 0.6944 , Val Acc: 36.2319
# Epoch: 1, Loss: 0.6944 , Val Acc: 35.5072
# Epoch: 2, Loss: 0.6945 , Val Acc: 36.2319
# Epoch: 3, Loss: 0.6944 , Val Acc: 35.5072
# Epoch: 4, Loss: 0.6944 , Val Acc: 36.2319
# Epoch: 5, Loss: 0.6944 , Val Acc: 36.2319
# Epoch: 6, Loss: 0.6944 , Val Acc: 35.5072
# Epoch: 7, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 8, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 9, Loss: 0.6943 , Val Acc: 35.5072
# Epoch: 10, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 11, Loss: 0.6943 , Val Acc: 35.5072
# Epoch: 12, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 13, Loss: 0.6943 , Val Acc: 35.5072
# Epoch: 14, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 15, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 16, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 17, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 18, Loss: 0.6942 , Val Acc: 36.9565
# Epoch: 19, Loss: 0.6942 , Val Acc: 36.2319
# Client: 9
# Epoch: 0, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 1, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 2, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 3, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 4, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 5, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 6, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 7, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 8, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 9, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 10, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 11, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 12, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 13, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 14, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 15, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 16, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 17, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 18, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 19, Loss: 0.8330 , Val Acc: 40.0000
# Client: 18
# Epoch: 0, Loss: 0.6546 , Val Acc: 39.2308
# Epoch: 1, Loss: 0.6549 , Val Acc: 40.7692
# Epoch: 2, Loss: 0.6545 , Val Acc: 39.2308
# Epoch: 3, Loss: 0.6547 , Val Acc: 40.7692
# Epoch: 4, Loss: 0.6548 , Val Acc: 39.2308
# Epoch: 5, Loss: 0.6548 , Val Acc: 40.7692
# Epoch: 6, Loss: 0.6546 , Val Acc: 39.2308
# Epoch: 7, Loss: 0.6546 , Val Acc: 40.7692
# Epoch: 8, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 9, Loss: 0.6541 , Val Acc: 40.7692
# Epoch: 10, Loss: 0.6541 , Val Acc: 40.0000
# Epoch: 11, Loss: 0.6542 , Val Acc: 39.2308
# Epoch: 12, Loss: 0.6540 , Val Acc: 40.7692
# Epoch: 13, Loss: 0.6543 , Val Acc: 39.2308
# Epoch: 14, Loss: 0.6544 , Val Acc: 40.7692
# Epoch: 15, Loss: 0.6544 , Val Acc: 39.2308
# Epoch: 16, Loss: 0.6545 , Val Acc: 40.7692
# Epoch: 17, Loss: 0.6544 , Val Acc: 39.2308
# Epoch: 18, Loss: 0.6545 , Val Acc: 40.7692
# Epoch: 19, Loss: 0.6543 , Val Acc: 39.2308
# Client: 11
# Epoch: 0, Loss: 0.7757 , Val Acc: 18.0556
# Epoch: 1, Loss: 0.7754 , Val Acc: 18.0556
# Epoch: 2, Loss: 0.7755 , Val Acc: 19.4444
# Epoch: 3, Loss: 0.7757 , Val Acc: 18.0556
# Epoch: 4, Loss: 0.7754 , Val Acc: 18.7500
# Epoch: 5, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 6, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 7, Loss: 0.7756 , Val Acc: 18.7500
# Epoch: 8, Loss: 0.7757 , Val Acc: 18.0556
# Epoch: 9, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 10, Loss: 0.7757 , Val Acc: 18.0556
# Epoch: 11, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 12, Loss: 0.7756 , Val Acc: 18.7500
# Epoch: 13, Loss: 0.7757 , Val Acc: 18.0556
# Early stopping
# Client: 12
# Epoch: 0, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 1, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 2, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 3, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 4, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 5, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 6, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 7, Loss: 0.7302 , Val Acc: 23.5294
# Epoch: 8, Loss: 0.7304 , Val Acc: 22.8758
# Epoch: 9, Loss: 0.7303 , Val Acc: 23.5294
# Epoch: 10, Loss: 0.7305 , Val Acc: 22.8758
# Epoch: 11, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 12, Loss: 0.7306 , Val Acc: 22.2222
# Epoch: 13, Loss: 0.7305 , Val Acc: 23.5294
# Epoch: 14, Loss: 0.7309 , Val Acc: 22.2222
# Early stopping
# Client: 10
# Epoch: 0, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 1, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 2, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 3, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 4, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 5, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 6, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 7, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 8, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 9, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 10, Loss: 0.7876 , Val Acc: 24.4275
# Early stopping
# Client: 7
# Epoch: 0, Loss: 0.6996 , Val Acc: 30.7190
# Epoch: 1, Loss: 0.6992 , Val Acc: 30.7190
# Epoch: 2, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 3, Loss: 0.6996 , Val Acc: 29.4118
# Epoch: 4, Loss: 0.6992 , Val Acc: 31.3726
# Epoch: 5, Loss: 0.6995 , Val Acc: 29.4118
# Epoch: 6, Loss: 0.6991 , Val Acc: 32.0261
# Epoch: 7, Loss: 0.6993 , Val Acc: 30.7190
# Epoch: 8, Loss: 0.6990 , Val Acc: 32.0261
# Epoch: 9, Loss: 0.6990 , Val Acc: 30.7190
# Epoch: 10, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 11, Loss: 0.6989 , Val Acc: 30.7190
# Epoch: 12, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 13, Loss: 0.6989 , Val Acc: 31.3726
# Epoch: 14, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 15, Loss: 0.6989 , Val Acc: 31.3726
# Epoch: 16, Loss: 0.6990 , Val Acc: 30.7190
# Epoch: 17, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 18, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 19, Loss: 0.6992 , Val Acc: 31.3726
# Client: 8
# Epoch: 0, Loss: 0.8713 , Val Acc: 40.0000
# Epoch: 1, Loss: 0.8712 , Val Acc: 41.3793
# Epoch: 2, Loss: 0.8713 , Val Acc: 40.0000
# Epoch: 3, Loss: 0.8712 , Val Acc: 42.0690
# Epoch: 4, Loss: 0.8714 , Val Acc: 39.3103
# Epoch: 5, Loss: 0.8712 , Val Acc: 42.0690
# Epoch: 6, Loss: 0.8714 , Val Acc: 39.3103
# Epoch: 7, Loss: 0.8712 , Val Acc: 42.0690
# Epoch: 8, Loss: 0.8715 , Val Acc: 39.3103
# Epoch: 9, Loss: 0.8713 , Val Acc: 42.0690
# Epoch: 10, Loss: 0.8715 , Val Acc: 39.3103
# Early stopping
# Client: 3
# Epoch: 0, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 1, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 2, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 3, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 4, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 5, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 6, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 7, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 8, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 9, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 10, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 11, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 12, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 13, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 14, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 15, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 16, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 17, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 18, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 19, Loss: 0.6155 , Val Acc: 30.9353
# Client: 19
# Epoch: 0, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 1, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 2, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 3, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 4, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 5, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 6, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 7, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 8, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 9, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 10, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 11, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 12, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 13, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 14, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 15, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 16, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 17, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 18, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 19, Loss: 0.7448 , Val Acc: 28.0822
# Server test error:
#  Accuracy: 50.2
#
# ---------------------Round 187---------------------
# Client: 5
# Epoch: 0, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 1, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 2, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 3, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 4, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 5, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 6, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 7, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 8, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 9, Loss: 0.7891 , Val Acc: 25.5319
# Early stopping
# Client: 0
# Epoch: 0, Loss: 0.7810 , Val Acc: 22.0690
# Epoch: 1, Loss: 0.7808 , Val Acc: 20.0000
# Epoch: 2, Loss: 0.7807 , Val Acc: 19.3103
# Epoch: 3, Loss: 0.7808 , Val Acc: 21.3793
# Epoch: 4, Loss: 0.7807 , Val Acc: 18.6207
# Epoch: 5, Loss: 0.7809 , Val Acc: 22.0690
# Epoch: 6, Loss: 0.7807 , Val Acc: 19.3103
# Epoch: 7, Loss: 0.7808 , Val Acc: 22.0690
# Epoch: 8, Loss: 0.7806 , Val Acc: 20.0000
# Epoch: 9, Loss: 0.7806 , Val Acc: 20.0000
# Epoch: 10, Loss: 0.7807 , Val Acc: 20.6897
# Epoch: 11, Loss: 0.7805 , Val Acc: 18.6207
# Epoch: 12, Loss: 0.7807 , Val Acc: 21.3793
# Epoch: 13, Loss: 0.7804 , Val Acc: 18.6207
# Epoch: 14, Loss: 0.7806 , Val Acc: 21.3793
# Epoch: 15, Loss: 0.7804 , Val Acc: 20.0000
# Epoch: 16, Loss: 0.7804 , Val Acc: 21.3793
# Epoch: 17, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 18, Loss: 0.7803 , Val Acc: 19.3103
# Epoch: 19, Loss: 0.7805 , Val Acc: 20.6897
# Client: 3
# Epoch: 0, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 1, Loss: 0.6155 , Val Acc: 31.6547
# Epoch: 2, Loss: 0.6154 , Val Acc: 30.9353
# Epoch: 3, Loss: 0.6155 , Val Acc: 31.6547
# Epoch: 4, Loss: 0.6154 , Val Acc: 30.9353
# Epoch: 5, Loss: 0.6156 , Val Acc: 30.9353
# Epoch: 6, Loss: 0.6154 , Val Acc: 31.6547
# Epoch: 7, Loss: 0.6156 , Val Acc: 30.9353
# Epoch: 8, Loss: 0.6154 , Val Acc: 31.6547
# Epoch: 9, Loss: 0.6156 , Val Acc: 30.9353
# Epoch: 10, Loss: 0.6153 , Val Acc: 31.6547
# Epoch: 11, Loss: 0.6157 , Val Acc: 30.2158
# Epoch: 12, Loss: 0.6152 , Val Acc: 30.9353
# Epoch: 13, Loss: 0.6159 , Val Acc: 30.2158
# Epoch: 14, Loss: 0.6152 , Val Acc: 30.9353
# Epoch: 15, Loss: 0.6160 , Val Acc: 30.2158
# Epoch: 16, Loss: 0.6151 , Val Acc: 31.6547
# Epoch: 17, Loss: 0.6162 , Val Acc: 30.2158
# Epoch: 18, Loss: 0.6151 , Val Acc: 31.6547
# Epoch: 19, Loss: 0.6163 , Val Acc: 30.2158
# Client: 4
# Epoch: 0, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 1, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 2, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 3, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 4, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 5, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 6, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 7, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 8, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 9, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 10, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 11, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 12, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 13, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 14, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 15, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 16, Loss: 0.7713 , Val Acc: 25.5639
# Early stopping
# Client: 1
# Epoch: 0, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 1, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 2, Loss: 0.8499 , Val Acc: 29.6552
# Epoch: 3, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 4, Loss: 0.8499 , Val Acc: 29.6552
# Epoch: 5, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 6, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 7, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 8, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 9, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 10, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 11, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 12, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 13, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 14, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 15, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 16, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 17, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 18, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 19, Loss: 0.8498 , Val Acc: 29.6552
# Client: 18
# Epoch: 0, Loss: 0.6544 , Val Acc: 40.7692
# Epoch: 1, Loss: 0.6542 , Val Acc: 39.2308
# Epoch: 2, Loss: 0.6543 , Val Acc: 40.7692
# Epoch: 3, Loss: 0.6543 , Val Acc: 40.0000
# Epoch: 4, Loss: 0.6542 , Val Acc: 40.7692
# Epoch: 5, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 6, Loss: 0.6543 , Val Acc: 40.0000
# Epoch: 7, Loss: 0.6544 , Val Acc: 40.7692
# Epoch: 8, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 9, Loss: 0.6546 , Val Acc: 40.7692
# Epoch: 10, Loss: 0.6545 , Val Acc: 40.0000
# Early stopping
# Client: 15
# Epoch: 0, Loss: 0.6643 , Val Acc: 30.0000
# Epoch: 1, Loss: 0.6647 , Val Acc: 30.0000
# Epoch: 2, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 3, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 4, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 5, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 6, Loss: 0.6647 , Val Acc: 30.0000
# Epoch: 7, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 8, Loss: 0.6646 , Val Acc: 29.2857
# Epoch: 9, Loss: 0.6645 , Val Acc: 30.0000
# Early stopping
# Client: 12
# Epoch: 0, Loss: 0.7313 , Val Acc: 22.2222
# Epoch: 1, Loss: 0.7309 , Val Acc: 23.5294
# Epoch: 2, Loss: 0.7311 , Val Acc: 22.2222
# Epoch: 3, Loss: 0.7307 , Val Acc: 23.5294
# Epoch: 4, Loss: 0.7306 , Val Acc: 22.8758
# Epoch: 5, Loss: 0.7306 , Val Acc: 22.8758
# Epoch: 6, Loss: 0.7305 , Val Acc: 23.5294
# Epoch: 7, Loss: 0.7308 , Val Acc: 22.8758
# Epoch: 8, Loss: 0.7307 , Val Acc: 22.8758
# Epoch: 9, Loss: 0.7308 , Val Acc: 22.8758
# Epoch: 10, Loss: 0.7307 , Val Acc: 23.5294
# Epoch: 11, Loss: 0.7306 , Val Acc: 22.8758
# Epoch: 12, Loss: 0.7305 , Val Acc: 22.8758
# Epoch: 13, Loss: 0.7304 , Val Acc: 23.5294
# Epoch: 14, Loss: 0.7306 , Val Acc: 22.8758
# Epoch: 15, Loss: 0.7304 , Val Acc: 23.5294
# Epoch: 16, Loss: 0.7305 , Val Acc: 22.8758
# Epoch: 17, Loss: 0.7304 , Val Acc: 23.5294
# Epoch: 18, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 19, Loss: 0.7303 , Val Acc: 22.8758
# Client: 7
# Epoch: 0, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 1, Loss: 0.6991 , Val Acc: 30.7190
# Epoch: 2, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 3, Loss: 0.6990 , Val Acc: 30.7190
# Epoch: 4, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 5, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 6, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 7, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 8, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 9, Loss: 0.6990 , Val Acc: 31.3726
# Early stopping
# Client: 13
# Epoch: 0, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 1, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 2, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 3, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 4, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 5, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 6, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 7, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 8, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 9, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 10, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 11, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 12, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 13, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 14, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 15, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 16, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 17, Loss: 0.7640 , Val Acc: 31.3869
# Early stopping
# Client: 10
# Epoch: 0, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 1, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 2, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 3, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 4, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 5, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 6, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 7, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 8, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 9, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 10, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 11, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 12, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 13, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 14, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 15, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 16, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 17, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 18, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 19, Loss: 0.7876 , Val Acc: 24.4275
# Client: 19
# Epoch: 0, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 1, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 2, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 3, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 4, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 5, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 6, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 7, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 8, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 9, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 10, Loss: 0.7448 , Val Acc: 28.0822
# Early stopping
# Client: 6
# Epoch: 0, Loss: 0.6942 , Val Acc: 34.7826
# Epoch: 1, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 2, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 3, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 4, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 5, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 6, Loss: 0.6942 , Val Acc: 34.7826
# Epoch: 7, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 8, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 9, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 10, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 11, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 12, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 13, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 14, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 15, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 16, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 17, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 18, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 19, Loss: 0.6942 , Val Acc: 36.2319
# Client: 16
# Epoch: 0, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 1, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 2, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 3, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 4, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 5, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 6, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 7, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 8, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 9, Loss: 0.7286 , Val Acc: 39.5349
# Early stopping
# Client: 8
# Epoch: 0, Loss: 0.8715 , Val Acc: 40.0000
# Epoch: 1, Loss: 0.8713 , Val Acc: 42.0690
# Epoch: 2, Loss: 0.8714 , Val Acc: 40.0000
# Epoch: 3, Loss: 0.8713 , Val Acc: 41.3793
# Epoch: 4, Loss: 0.8713 , Val Acc: 40.6897
# Epoch: 5, Loss: 0.8713 , Val Acc: 40.6897
# Epoch: 6, Loss: 0.8713 , Val Acc: 40.6897
# Epoch: 7, Loss: 0.8713 , Val Acc: 40.0000
# Epoch: 8, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 9, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 10, Loss: 0.8712 , Val Acc: 41.3793
# Epoch: 11, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 12, Loss: 0.8712 , Val Acc: 41.3793
# Epoch: 13, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 14, Loss: 0.8712 , Val Acc: 41.3793
# Epoch: 15, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 16, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 17, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 18, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 19, Loss: 0.8712 , Val Acc: 40.6897
# Client: 17
# Epoch: 0, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 1, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 2, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 3, Loss: 0.8499 , Val Acc: 33.3333
# Epoch: 4, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 5, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 6, Loss: 0.8500 , Val Acc: 33.3333
# Epoch: 7, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 8, Loss: 0.8500 , Val Acc: 34.0580
# Epoch: 9, Loss: 0.8499 , Val Acc: 34.7826
# Early stopping
# Client: 2
# Epoch: 0, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 1, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 2, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 3, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 4, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 5, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 6, Loss: 0.7528 , Val Acc: 24.6835
# Epoch: 7, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 8, Loss: 0.7528 , Val Acc: 24.6835
# Epoch: 9, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 10, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 11, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 12, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 13, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 14, Loss: 0.7526 , Val Acc: 24.0506
# Epoch: 15, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 16, Loss: 0.7526 , Val Acc: 24.0506
# Epoch: 17, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 18, Loss: 0.7526 , Val Acc: 24.0506
# Epoch: 19, Loss: 0.7527 , Val Acc: 24.6835
# Client: 14
# Epoch: 0, Loss: 0.6810 , Val Acc: 37.5000
# Epoch: 1, Loss: 0.6808 , Val Acc: 35.4167
# Epoch: 2, Loss: 0.6809 , Val Acc: 36.8056
# Epoch: 3, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 4, Loss: 0.6809 , Val Acc: 36.8056
# Epoch: 5, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 6, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 7, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 8, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 9, Loss: 0.6808 , Val Acc: 37.5000
# Epoch: 10, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 11, Loss: 0.6808 , Val Acc: 37.5000
# Epoch: 12, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 13, Loss: 0.6808 , Val Acc: 37.5000
# Epoch: 14, Loss: 0.6807 , Val Acc: 36.1111
# Epoch: 15, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 16, Loss: 0.6807 , Val Acc: 36.1111
# Epoch: 17, Loss: 0.6809 , Val Acc: 36.8056
# Epoch: 18, Loss: 0.6807 , Val Acc: 36.8056
# Epoch: 19, Loss: 0.6809 , Val Acc: 36.8056
# Client: 9
# Epoch: 0, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 1, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 2, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 3, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 4, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 5, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 6, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 7, Loss: 0.8330 , Val Acc: 40.7407
# Epoch: 8, Loss: 0.8331 , Val Acc: 40.0000
# Epoch: 9, Loss: 0.8330 , Val Acc: 40.7407
# Epoch: 10, Loss: 0.8331 , Val Acc: 40.0000
# Epoch: 11, Loss: 0.8330 , Val Acc: 41.4815
# Epoch: 12, Loss: 0.8332 , Val Acc: 38.5185
# Epoch: 13, Loss: 0.8335 , Val Acc: 41.4815
# Epoch: 14, Loss: 0.8340 , Val Acc: 35.5556
# Epoch: 15, Loss: 0.8337 , Val Acc: 42.9630
# Epoch: 16, Loss: 0.8343 , Val Acc: 34.0741
# Early stopping
# Client: 11
# Epoch: 0, Loss: 0.7757 , Val Acc: 18.0556
# Epoch: 1, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 2, Loss: 0.7756 , Val Acc: 18.7500
# Epoch: 3, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 4, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 5, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 6, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 7, Loss: 0.7756 , Val Acc: 18.7500
# Epoch: 8, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 9, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 10, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 11, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 12, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 13, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 14, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 15, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 16, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 17, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 18, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 19, Loss: 0.7755 , Val Acc: 18.0556
# Server test error:
#  Accuracy: 50.2
#
# ---------------------Round 188---------------------
# Client: 16
# Epoch: 0, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 1, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 2, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 3, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 4, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 5, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 6, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 7, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 8, Loss: 0.7287 , Val Acc: 38.7597
# Epoch: 9, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 10, Loss: 0.7287 , Val Acc: 38.7597
# Epoch: 11, Loss: 0.7286 , Val Acc: 39.5349
# Early stopping
# Client: 2
# Epoch: 0, Loss: 0.7526 , Val Acc: 24.0506
# Epoch: 1, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 2, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 3, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 4, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 5, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 6, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 7, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 8, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 9, Loss: 0.7527 , Val Acc: 24.6835
# Early stopping
# Client: 15
# Epoch: 0, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 1, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 2, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 3, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 4, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 5, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 6, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 7, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 8, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 9, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 10, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 11, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 12, Loss: 0.6645 , Val Acc: 30.0000
# Early stopping
# Client: 7
# Epoch: 0, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 1, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 2, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 3, Loss: 0.6989 , Val Acc: 31.3726
# Epoch: 4, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 5, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 6, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 7, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 8, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 9, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 10, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 11, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 12, Loss: 0.6990 , Val Acc: 31.3726
# Early stopping
# Client: 6
# Epoch: 0, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 1, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 2, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 3, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 4, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 5, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 6, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 7, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 8, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 9, Loss: 0.6941 , Val Acc: 36.2319
# Epoch: 10, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 11, Loss: 0.6941 , Val Acc: 36.2319
# Epoch: 12, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 13, Loss: 0.6941 , Val Acc: 36.2319
# Epoch: 14, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 15, Loss: 0.6941 , Val Acc: 36.2319
# Epoch: 16, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 17, Loss: 0.6941 , Val Acc: 35.5072
# Epoch: 18, Loss: 0.6943 , Val Acc: 36.2319
# Epoch: 19, Loss: 0.6941 , Val Acc: 35.5072
# Client: 0
# Epoch: 0, Loss: 0.7803 , Val Acc: 18.6207
# Epoch: 1, Loss: 0.7806 , Val Acc: 21.3793
# Epoch: 2, Loss: 0.7804 , Val Acc: 19.3103
# Epoch: 3, Loss: 0.7805 , Val Acc: 21.3793
# Epoch: 4, Loss: 0.7805 , Val Acc: 20.0000
# Epoch: 5, Loss: 0.7804 , Val Acc: 20.0000
# Epoch: 6, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 7, Loss: 0.7804 , Val Acc: 19.3103
# Epoch: 8, Loss: 0.7806 , Val Acc: 20.6897
# Epoch: 9, Loss: 0.7804 , Val Acc: 18.6207
# Early stopping
# Client: 3
# Epoch: 0, Loss: 0.6152 , Val Acc: 31.6547
# Epoch: 1, Loss: 0.6161 , Val Acc: 30.2158
# Epoch: 2, Loss: 0.6154 , Val Acc: 32.3741
# Epoch: 3, Loss: 0.6158 , Val Acc: 31.6547
# Epoch: 4, Loss: 0.6156 , Val Acc: 30.9353
# Epoch: 5, Loss: 0.6155 , Val Acc: 32.3741
# Epoch: 6, Loss: 0.6159 , Val Acc: 30.9353
# Epoch: 7, Loss: 0.6153 , Val Acc: 31.6547
# Epoch: 8, Loss: 0.6160 , Val Acc: 30.9353
# Epoch: 9, Loss: 0.6153 , Val Acc: 31.6547
# Early stopping
# Client: 11
# Epoch: 0, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 1, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 2, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 3, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 4, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 5, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 6, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 7, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 8, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 9, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 10, Loss: 0.7756 , Val Acc: 18.0556
# Early stopping
# Client: 19
# Epoch: 0, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 1, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 2, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 3, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 4, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 5, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 6, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 7, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 8, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 9, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 10, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 11, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 12, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 13, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 14, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 15, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 16, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 17, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 18, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 19, Loss: 0.7448 , Val Acc: 28.0822
# Client: 14
# Epoch: 0, Loss: 0.6807 , Val Acc: 36.8056
# Epoch: 1, Loss: 0.6809 , Val Acc: 36.1111
# Epoch: 2, Loss: 0.6807 , Val Acc: 36.8056
# Epoch: 3, Loss: 0.6810 , Val Acc: 36.1111
# Epoch: 4, Loss: 0.6807 , Val Acc: 36.8056
# Epoch: 5, Loss: 0.6810 , Val Acc: 36.1111
# Epoch: 6, Loss: 0.6807 , Val Acc: 36.8056
# Epoch: 7, Loss: 0.6811 , Val Acc: 36.1111
# Epoch: 8, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 9, Loss: 0.6814 , Val Acc: 36.8056
# Epoch: 10, Loss: 0.6810 , Val Acc: 36.8056
# Epoch: 11, Loss: 0.6811 , Val Acc: 37.5000
# Early stopping
# Client: 4
# Epoch: 0, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 1, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 2, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 3, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 4, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 5, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 6, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 7, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 8, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 9, Loss: 0.7713 , Val Acc: 25.5639
# Early stopping
# Client: 17
# Epoch: 0, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 1, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 2, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 3, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 4, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 5, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 6, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 7, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 8, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 9, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 10, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 11, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 12, Loss: 0.8499 , Val Acc: 33.3333
# Epoch: 13, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 14, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 15, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 16, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 17, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 18, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 19, Loss: 0.8499 , Val Acc: 34.0580
# Client: 13
# Epoch: 0, Loss: 0.7640 , Val Acc: 31.3869
# Epoch: 1, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 2, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 3, Loss: 0.7641 , Val Acc: 29.9270
# Epoch: 4, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 5, Loss: 0.7641 , Val Acc: 29.9270
# Epoch: 6, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 7, Loss: 0.7642 , Val Acc: 30.6569
# Epoch: 8, Loss: 0.7643 , Val Acc: 29.9270
# Epoch: 9, Loss: 0.7644 , Val Acc: 31.3869
# Epoch: 10, Loss: 0.7643 , Val Acc: 29.9270
# Early stopping
# Client: 1
# Epoch: 0, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 1, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 2, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 3, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 4, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 5, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 6, Loss: 0.8497 , Val Acc: 29.6552
# Epoch: 7, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 8, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 9, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 10, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 11, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 12, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 13, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 14, Loss: 0.8498 , Val Acc: 29.6552
# Epoch: 15, Loss: 0.8498 , Val Acc: 29.6552
# Early stopping
# Client: 10
# Epoch: 0, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 1, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 2, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 3, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 4, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 5, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 6, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 7, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 8, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 9, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 10, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 11, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 12, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 13, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 14, Loss: 0.7875 , Val Acc: 24.4275
# Epoch: 15, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 16, Loss: 0.7875 , Val Acc: 23.6641
# Epoch: 17, Loss: 0.7876 , Val Acc: 24.4275
# Epoch: 18, Loss: 0.7875 , Val Acc: 23.6641
# Epoch: 19, Loss: 0.7877 , Val Acc: 24.4275
# Client: 5
# Epoch: 0, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 1, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 2, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 3, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 4, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 5, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 6, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 7, Loss: 0.7890 , Val Acc: 25.5319
# Epoch: 8, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 9, Loss: 0.7890 , Val Acc: 25.5319
# Epoch: 10, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 11, Loss: 0.7890 , Val Acc: 25.5319
# Epoch: 12, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 13, Loss: 0.7890 , Val Acc: 25.5319
# Epoch: 14, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 15, Loss: 0.7890 , Val Acc: 26.2411
# Epoch: 16, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 17, Loss: 0.7890 , Val Acc: 26.2411
# Epoch: 18, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 19, Loss: 0.7891 , Val Acc: 26.2411
# Client: 12
# Epoch: 0, Loss: 0.7302 , Val Acc: 23.5294
# Epoch: 1, Loss: 0.7304 , Val Acc: 22.8758
# Epoch: 2, Loss: 0.7302 , Val Acc: 23.5294
# Epoch: 3, Loss: 0.7304 , Val Acc: 22.8758
# Epoch: 4, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 5, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 6, Loss: 0.7304 , Val Acc: 22.8758
# Epoch: 7, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 8, Loss: 0.7304 , Val Acc: 22.8758
# Epoch: 9, Loss: 0.7302 , Val Acc: 22.8758
# Early stopping
# Client: 9
# Epoch: 0, Loss: 0.8349 , Val Acc: 34.0741
# Epoch: 1, Loss: 0.8343 , Val Acc: 41.4815
# Epoch: 2, Loss: 0.8343 , Val Acc: 39.2593
# Epoch: 3, Loss: 0.8339 , Val Acc: 40.0000
# Epoch: 4, Loss: 0.8340 , Val Acc: 41.4815
# Epoch: 5, Loss: 0.8342 , Val Acc: 37.7778
# Epoch: 6, Loss: 0.8341 , Val Acc: 41.4815
# Epoch: 7, Loss: 0.8341 , Val Acc: 37.0370
# Epoch: 8, Loss: 0.8336 , Val Acc: 41.4815
# Epoch: 9, Loss: 0.8334 , Val Acc: 40.0000
# Epoch: 10, Loss: 0.8334 , Val Acc: 40.0000
# Epoch: 11, Loss: 0.8334 , Val Acc: 41.4815
# Epoch: 12, Loss: 0.8334 , Val Acc: 37.7778
# Epoch: 13, Loss: 0.8333 , Val Acc: 42.2222
# Epoch: 14, Loss: 0.8332 , Val Acc: 40.0000
# Epoch: 15, Loss: 0.8329 , Val Acc: 40.0000
# Epoch: 16, Loss: 0.8330 , Val Acc: 40.0000
# Epoch: 17, Loss: 0.8331 , Val Acc: 40.0000
# Epoch: 18, Loss: 0.8330 , Val Acc: 41.4815
# Epoch: 19, Loss: 0.8332 , Val Acc: 40.0000
# Client: 8
# Epoch: 0, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 1, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 2, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 3, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 4, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 5, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 6, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 7, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 8, Loss: 0.8712 , Val Acc: 40.0000
# Epoch: 9, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 10, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 11, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 12, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 13, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 14, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 15, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 16, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 17, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 18, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 19, Loss: 0.8712 , Val Acc: 40.6897
# Client: 18
# ...
# Epoch: 16, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 17, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 18, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 19, Loss: 0.7804 , Val Acc: 20.6897
# Client: 15
# Epoch: 0, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 1, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 2, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 3, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 4, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 5, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 6, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 7, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 8, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 9, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 10, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 11, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 12, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 13, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 14, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 15, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 16, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 17, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 18, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 19, Loss: 0.6644 , Val Acc: 30.0000
# Client: 13
# Epoch: 0, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 1, Loss: 0.7641 , Val Acc: 31.3869
# Epoch: 2, Loss: 0.7642 , Val Acc: 30.6569
# Epoch: 3, Loss: 0.7639 , Val Acc: 30.6569
# Epoch: 4, Loss: 0.7642 , Val Acc: 30.6569
# Epoch: 5, Loss: 0.7639 , Val Acc: 29.9270
# Epoch: 6, Loss: 0.7642 , Val Acc: 30.6569
# Epoch: 7, Loss: 0.7638 , Val Acc: 29.9270
# Epoch: 8, Loss: 0.7642 , Val Acc: 30.6569
# Epoch: 9, Loss: 0.7639 , Val Acc: 29.9270
# Epoch: 10, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 11, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 12, Loss: 0.7640 , Val Acc: 31.3869
# Epoch: 13, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 14, Loss: 0.7639 , Val Acc: 30.6569
# Epoch: 15, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 16, Loss: 0.7639 , Val Acc: 30.6569
# Early stopping
# Client: 19
# Epoch: 0, Loss: 0.7447 , Val Acc: 28.0822
# Epoch: 1, Loss: 0.7448 , Val Acc: 28.7671
# Epoch: 2, Loss: 0.7447 , Val Acc: 29.4521
# Epoch: 3, Loss: 0.7447 , Val Acc: 28.0822
# Epoch: 4, Loss: 0.7448 , Val Acc: 28.7671
# Epoch: 5, Loss: 0.7447 , Val Acc: 28.0822
# Epoch: 6, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 7, Loss: 0.7447 , Val Acc: 28.7671
# Epoch: 8, Loss: 0.7448 , Val Acc: 27.3973
# Epoch: 9, Loss: 0.7448 , Val Acc: 29.4521
# Epoch: 10, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 11, Loss: 0.7449 , Val Acc: 28.7671
# Epoch: 12, Loss: 0.7448 , Val Acc: 27.3973
# Epoch: 13, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 14, Loss: 0.7449 , Val Acc: 28.7671
# Early stopping
# Client: 2
# Epoch: 0, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 1, Loss: 0.7526 , Val Acc: 24.6835
# Epoch: 2, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 3, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 4, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 5, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 6, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 7, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 8, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 9, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 10, Loss: 0.7527 , Val Acc: 24.6835
# Early stopping
# Server test error:
#  Accuracy: 50.2
#
# ---------------------Round 199---------------------
# Client: 10
# Epoch: 0, Loss: 0.7878 , Val Acc: 23.6641
# Epoch: 1, Loss: 0.7878 , Val Acc: 25.9542
# Epoch: 2, Loss: 0.7879 , Val Acc: 23.6641
# Epoch: 3, Loss: 0.7879 , Val Acc: 25.1908
# Epoch: 4, Loss: 0.7879 , Val Acc: 23.6641
# Epoch: 5, Loss: 0.7879 , Val Acc: 25.1908
# Epoch: 6, Loss: 0.7880 , Val Acc: 23.6641
# Epoch: 7, Loss: 0.7879 , Val Acc: 25.1908
# Epoch: 8, Loss: 0.7879 , Val Acc: 23.6641
# Epoch: 9, Loss: 0.7879 , Val Acc: 23.6641
# Early stopping
# Client: 14
# Epoch: 0, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 1, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 2, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 3, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 4, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 5, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 6, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 7, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 8, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 9, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 10, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 11, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 12, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 13, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 14, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 15, Loss: 0.6808 , Val Acc: 36.1111
# Epoch: 16, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 17, Loss: 0.6809 , Val Acc: 35.4167
# Epoch: 18, Loss: 0.6808 , Val Acc: 36.8056
# Epoch: 19, Loss: 0.6809 , Val Acc: 35.4167
# Client: 3
# Epoch: 0, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 1, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 2, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 3, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 4, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 5, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 6, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 7, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 8, Loss: 0.6155 , Val Acc: 30.9353
# Epoch: 9, Loss: 0.6155 , Val Acc: 30.9353
# Early stopping
# Client: 15
# Epoch: 0, Loss: 0.6647 , Val Acc: 28.5714
# Epoch: 1, Loss: 0.6644 , Val Acc: 30.0000
# Epoch: 2, Loss: 0.6649 , Val Acc: 28.5714
# Epoch: 3, Loss: 0.6645 , Val Acc: 30.0000
# Epoch: 4, Loss: 0.6652 , Val Acc: 27.1429
# Epoch: 5, Loss: 0.6646 , Val Acc: 31.4286
# Epoch: 6, Loss: 0.6657 , Val Acc: 27.1429
# Epoch: 7, Loss: 0.6648 , Val Acc: 31.4286
# Epoch: 8, Loss: 0.6657 , Val Acc: 27.1429
# Epoch: 9, Loss: 0.6646 , Val Acc: 30.0000
# Epoch: 10, Loss: 0.6652 , Val Acc: 28.5714
# Early stopping
# Client: 6
# Epoch: 0, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 1, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 2, Loss: 0.6942 , Val Acc: 36.2319
# Epoch: 3, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 4, Loss: 0.6942 , Val Acc: 36.9565
# Epoch: 5, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 6, Loss: 0.6942 , Val Acc: 36.9565
# Epoch: 7, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 8, Loss: 0.6943 , Val Acc: 37.6812
# Epoch: 9, Loss: 0.6942 , Val Acc: 35.5072
# Epoch: 10, Loss: 0.6943 , Val Acc: 36.9565
# Early stopping
# Client: 1
# Epoch: 0, Loss: 0.8499 , Val Acc: 31.7241
# Epoch: 1, Loss: 0.8499 , Val Acc: 29.6552
# Epoch: 2, Loss: 0.8501 , Val Acc: 31.7241
# Epoch: 3, Loss: 0.8501 , Val Acc: 29.6552
# Epoch: 4, Loss: 0.8502 , Val Acc: 31.7241
# Epoch: 5, Loss: 0.8503 , Val Acc: 29.6552
# Epoch: 6, Loss: 0.8503 , Val Acc: 31.7241
# Epoch: 7, Loss: 0.8501 , Val Acc: 29.6552
# Epoch: 8, Loss: 0.8502 , Val Acc: 30.3448
# Epoch: 9, Loss: 0.8501 , Val Acc: 29.6552
# Early stopping
# Client: 16
# Epoch: 0, Loss: 0.7289 , Val Acc: 40.3101
# Epoch: 1, Loss: 0.7288 , Val Acc: 39.5349
# Epoch: 2, Loss: 0.7289 , Val Acc: 39.5349
# Epoch: 3, Loss: 0.7288 , Val Acc: 40.3101
# Epoch: 4, Loss: 0.7288 , Val Acc: 38.7597
# Epoch: 5, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 6, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 7, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 8, Loss: 0.7286 , Val Acc: 38.7597
# Epoch: 9, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 10, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 11, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 12, Loss: 0.7286 , Val Acc: 39.5349
# Epoch: 13, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 14, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 15, Loss: 0.7287 , Val Acc: 38.7597
# Epoch: 16, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 17, Loss: 0.7287 , Val Acc: 39.5349
# Epoch: 18, Loss: 0.7287 , Val Acc: 40.3101
# Epoch: 19, Loss: 0.7287 , Val Acc: 39.5349
# Client: 19
# Epoch: 0, Loss: 0.7449 , Val Acc: 28.7671
# Epoch: 1, Loss: 0.7449 , Val Acc: 27.3973
# Epoch: 2, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 3, Loss: 0.7449 , Val Acc: 27.3973
# Epoch: 4, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 5, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 6, Loss: 0.7449 , Val Acc: 27.3973
# Epoch: 7, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 8, Loss: 0.7448 , Val Acc: 27.3973
# Epoch: 9, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 10, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 11, Loss: 0.7449 , Val Acc: 28.0822
# Epoch: 12, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 13, Loss: 0.7448 , Val Acc: 27.3973
# Epoch: 14, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 15, Loss: 0.7448 , Val Acc: 27.3973
# Epoch: 16, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 17, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 18, Loss: 0.7448 , Val Acc: 28.0822
# Epoch: 19, Loss: 0.7448 , Val Acc: 28.0822
# Client: 13
# Epoch: 0, Loss: 0.7639 , Val Acc: 30.6569
# Epoch: 1, Loss: 0.7641 , Val Acc: 31.3869
# Epoch: 2, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 3, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 4, Loss: 0.7640 , Val Acc: 29.9270
# Epoch: 5, Loss: 0.7640 , Val Acc: 31.3869
# Epoch: 6, Loss: 0.7640 , Val Acc: 30.6569
# Epoch: 7, Loss: 0.7640 , Val Acc: 31.3869
# Epoch: 8, Loss: 0.7641 , Val Acc: 30.6569
# Epoch: 9, Loss: 0.7640 , Val Acc: 31.3869
# Early stopping
# Client: 11
# Epoch: 0, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 1, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 2, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 3, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 4, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 5, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 6, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 7, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 8, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 9, Loss: 0.7755 , Val Acc: 18.0556
# Epoch: 10, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 11, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 12, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 13, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 14, Loss: 0.7756 , Val Acc: 18.0556
# Epoch: 15, Loss: 0.7755 , Val Acc: 18.7500
# Epoch: 16, Loss: 0.7757 , Val Acc: 18.0556
# Epoch: 17, Loss: 0.7754 , Val Acc: 18.7500
# Epoch: 18, Loss: 0.7758 , Val Acc: 18.0556
# Epoch: 19, Loss: 0.7754 , Val Acc: 18.0556
# Client: 9
# Epoch: 0, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 1, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 2, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 3, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 4, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 5, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 6, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 7, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 8, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 9, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 10, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 11, Loss: 0.8330 , Val Acc: 39.2593
# Epoch: 12, Loss: 0.8330 , Val Acc: 39.2593
# Early stopping
# Client: 8
# Epoch: 0, Loss: 0.8713 , Val Acc: 40.6897
# Epoch: 1, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 2, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 3, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 4, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 5, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 6, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 7, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 8, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 9, Loss: 0.8712 , Val Acc: 40.6897
# Epoch: 10, Loss: 0.8712 , Val Acc: 40.6897
# Early stopping
# Client: 5
# Epoch: 0, Loss: 0.7896 , Val Acc: 24.8227
# Epoch: 1, Loss: 0.7893 , Val Acc: 24.8227
# Epoch: 2, Loss: 0.7894 , Val Acc: 26.2411
# Epoch: 3, Loss: 0.7894 , Val Acc: 24.1135
# Epoch: 4, Loss: 0.7894 , Val Acc: 26.2411
# Epoch: 5, Loss: 0.7895 , Val Acc: 24.1135
# Epoch: 6, Loss: 0.7892 , Val Acc: 25.5319
# Epoch: 7, Loss: 0.7894 , Val Acc: 24.8227
# Epoch: 8, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 9, Loss: 0.7892 , Val Acc: 26.9504
# Epoch: 10, Loss: 0.7891 , Val Acc: 24.8227
# Epoch: 11, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 12, Loss: 0.7892 , Val Acc: 24.8227
# Epoch: 13, Loss: 0.7890 , Val Acc: 26.2411
# Epoch: 14, Loss: 0.7892 , Val Acc: 24.8227
# Epoch: 15, Loss: 0.7890 , Val Acc: 26.2411
# Epoch: 16, Loss: 0.7891 , Val Acc: 25.5319
# Epoch: 17, Loss: 0.7890 , Val Acc: 24.8227
# Epoch: 18, Loss: 0.7891 , Val Acc: 26.9504
# Epoch: 19, Loss: 0.7891 , Val Acc: 24.8227
# Client: 4
# Epoch: 0, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 1, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 2, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 3, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 4, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 5, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 6, Loss: 0.7714 , Val Acc: 25.5639
# Epoch: 7, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 8, Loss: 0.7713 , Val Acc: 25.5639
# Epoch: 9, Loss: 0.7713 , Val Acc: 25.5639
# Early stopping
# Client: 12
# Epoch: 0, Loss: 0.7306 , Val Acc: 23.5294
# Epoch: 1, Loss: 0.7309 , Val Acc: 22.8758
# Epoch: 2, Loss: 0.7308 , Val Acc: 22.8758
# Epoch: 3, Loss: 0.7305 , Val Acc: 22.8758
# Epoch: 4, Loss: 0.7310 , Val Acc: 22.8758
# Epoch: 5, Loss: 0.7303 , Val Acc: 23.5294
# Epoch: 6, Loss: 0.7308 , Val Acc: 22.8758
# Epoch: 7, Loss: 0.7303 , Val Acc: 23.5294
# Epoch: 8, Loss: 0.7304 , Val Acc: 22.8758
# Epoch: 9, Loss: 0.7305 , Val Acc: 22.8758
# Epoch: 10, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 11, Loss: 0.7306 , Val Acc: 22.8758
# Epoch: 12, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 13, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 14, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 15, Loss: 0.7302 , Val Acc: 22.8758
# Epoch: 16, Loss: 0.7305 , Val Acc: 22.8758
# Epoch: 17, Loss: 0.7301 , Val Acc: 22.8758
# Epoch: 18, Loss: 0.7303 , Val Acc: 22.8758
# Epoch: 19, Loss: 0.7302 , Val Acc: 22.8758
# Client: 2
# Epoch: 0, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 1, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 2, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 3, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 4, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 5, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 6, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 7, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 8, Loss: 0.7527 , Val Acc: 24.6835
# Epoch: 9, Loss: 0.7527 , Val Acc: 23.4177
# Epoch: 10, Loss: 0.7527 , Val Acc: 25.3165
# Epoch: 11, Loss: 0.7527 , Val Acc: 24.0506
# Epoch: 12, Loss: 0.7528 , Val Acc: 25.3165
# Early stopping
# Client: 0
# Epoch: 0, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 1, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 2, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 3, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 4, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 5, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 6, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 7, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 8, Loss: 0.7805 , Val Acc: 20.6897
# Epoch: 9, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 10, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 11, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 12, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 13, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 14, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 15, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 16, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 17, Loss: 0.7804 , Val Acc: 20.6897
# Epoch: 18, Loss: 0.7804 , Val Acc: 20.6897
# Early stopping
# Client: 18
# Epoch: 0, Loss: 0.6542 , Val Acc: 39.2308
# Epoch: 1, Loss: 0.6545 , Val Acc: 40.7692
# Epoch: 2, Loss: 0.6544 , Val Acc: 39.2308
# Epoch: 3, Loss: 0.6541 , Val Acc: 40.7692
# Epoch: 4, Loss: 0.6543 , Val Acc: 40.0000
# Epoch: 5, Loss: 0.6541 , Val Acc: 40.0000
# Epoch: 6, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 7, Loss: 0.6539 , Val Acc: 40.0000
# Epoch: 8, Loss: 0.6545 , Val Acc: 40.0000
# Epoch: 9, Loss: 0.6544 , Val Acc: 40.0000
# Epoch: 10, Loss: 0.6546 , Val Acc: 40.0000
# Epoch: 11, Loss: 0.6545 , Val Acc: 40.0000
# Epoch: 12, Loss: 0.6547 , Val Acc: 40.0000
# Epoch: 13, Loss: 0.6549 , Val Acc: 40.0000
# Epoch: 14, Loss: 0.6548 , Val Acc: 40.0000
# Epoch: 15, Loss: 0.6545 , Val Acc: 40.0000
# Epoch: 16, Loss: 0.6543 , Val Acc: 40.7692
# Early stopping
# Client: 17
# Epoch: 0, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 1, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 2, Loss: 0.8499 , Val Acc: 34.7826
# Epoch: 3, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 4, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 5, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 6, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 7, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 8, Loss: 0.8499 , Val Acc: 34.0580
# Epoch: 9, Loss: 0.8499 , Val Acc: 34.0580
# Early stopping
# Client: 7
# Epoch: 0, Loss: 0.6995 , Val Acc: 32.0261
# Epoch: 1, Loss: 0.6999 , Val Acc: 30.7190
# Epoch: 2, Loss: 0.6995 , Val Acc: 31.3726
# Epoch: 3, Loss: 0.6995 , Val Acc: 30.0654
# Epoch: 4, Loss: 0.6992 , Val Acc: 30.0654
# Epoch: 5, Loss: 0.6995 , Val Acc: 31.3726
# Epoch: 6, Loss: 0.6993 , Val Acc: 30.7190
# Epoch: 7, Loss: 0.6993 , Val Acc: 30.7190
# Epoch: 8, Loss: 0.6994 , Val Acc: 29.4118
# Epoch: 9, Loss: 0.6993 , Val Acc: 30.7190
# Epoch: 10, Loss: 0.6995 , Val Acc: 30.0654
# Epoch: 11, Loss: 0.6992 , Val Acc: 31.3726
# Epoch: 12, Loss: 0.6993 , Val Acc: 31.3726
# Epoch: 13, Loss: 0.6991 , Val Acc: 30.7190
# Epoch: 14, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 15, Loss: 0.6991 , Val Acc: 30.7190
# Epoch: 16, Loss: 0.6991 , Val Acc: 31.3726
# Epoch: 17, Loss: 0.6991 , Val Acc: 30.7190
# Epoch: 18, Loss: 0.6990 , Val Acc: 31.3726
# Epoch: 19, Loss: 0.6990 , Val Acc: 31.3726
# Server test error:
#  Accuracy: 50.2
#
# --------------------Finally Test--------------------
